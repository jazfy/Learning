# %%
# 查看当前挂载的数据集目录
# !ls /home/kesci/input/

# %%
# 查看个人持久化工作区文件
# !ls /home/kesci/work/

# %%
# 查看当前kernerl下的package
# !pip list --format=columns

# %%
# 显示cell运行时长
# %load_ext klab-autotime

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:278: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# time: 27.6 s

# %%
X = np.array([[6], [8], [10], [14], [18]]).reshape(-1,1)
y = [7,9,13,17.5,18]
# Out:
# time: 1.38 ms

# %%
plt.figure()
plt.title('Pizza price plotted against diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(X,y,'k')
plt.axis([0,25,0,25])
plt.grid(True)
plt.show()
# Out:
# <img src="https://cdn.kesci.com/rt_upload/CBE917C92D45483AA721C48B079C34B4/paocnuefbd.png">
# time: 197 ms

# %%
#加载 sklearn 线性回归模块
from sklearn.linear_model import LinearRegression
model = LinearRegression() #实例化
model.fit(X,y) #传入训练集
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# time: 236 ms

# %%
#预测新值
test_pizza = np.array([[12]])
predicted_price = model.predict(test_pizza)[0]
print('A 12"pizza should cost:$%.2f'%predicted_price)
print('Residual sum of squares : %.2f'% np.mean((model.predict(X) - y) ** 2))
# Out:
# A 12"pizza should cost:$13.68
# Residual sum of squares : 1.75
# time: 66 ms

# %% [markdown]
# - 方差

# %%
X = np.array([[6],[8],[10],[14],[18]]).reshape(-1,1)
x_bar = X.mean()
print(x_bar)
# Out:
# 11.2
# time: 99.7 ms

# %%
variance = ((X - x_bar) ** 2).sum() / (X.shape[0] - 1)
print(variance)
# Out:
# 23.2
# time: 48.7 ms

# %%
#numpy 内置函数计算方差
print(np.var(X,ddof=1))
# Out:
# 23.2
# time: 1.09 ms

# %% [markdown]
# - 协方差

# %%
y = np.array([7,9,13,17.5,18])
# Out:
# time: 973 µs

# %%
y_bar = y.mean()
# Out:
# time: 891 µs

# %%
covariance = np.multiply((X - x_bar).transpose(), y - y_bar).sum() / (X.shape[0] - 1)
# Out:
# time: 1.21 ms

# %%
print(covariance)
# Out:
# 22.65
# time: 903 µs

# %%
#numpy 内置函数计算协方差
print(np.cov(X.transpose(),y)[0][1])
# Out:
# 22.650000000000002
# time: 82.3 ms

# %% [markdown]
# - 评估模型

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
# Out:
# time: 898 µs

# %%
X_train = np.array([6,8,10,14,18]).reshape(-1,1)
y_train = [7,9,13,17.5,18]

X_test = np.array([8,9,11,16,12]).reshape(-1,1)
y_test = [11,8.5,15,18,11]

model = LinearRegression() #实例化
model.fit(X_train,y_train) #传入训练集
r_squared = model.score(X_test,y_test) #评估测试集 |X 大写代表向量
print(r_squared)
# Out:
# 0.6620052929422553
# time: 3.41 ms
